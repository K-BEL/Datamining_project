# %%
import os
#os.chdir("C:\\Users\\Pc\\Desktop\\Projet DM&DV")
os.chdir(r"C:\Users\LENOVO\Desktop\cours\S5\Datamining\Project\Datasets")
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\LENOVO\\Desktop\\cours\\S5\\Datamining\\Project\\Datasets'

# %%
import pandas as pd
df_Vehicles = pd.read_csv('Vehicles.csv', header = 0, sep=',')
df_Casualties = pd.read_csv('Casualties.csv', header = 0, sep=',')
df_Accidents = pd.read_csv('Accidents.csv', header = 0, sep=',')
# Out:
# C:\Users\LENOVO\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_Casualties
# Out:
#         Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0        200501BS00001                  1                   1               3
# 1        200501BS00002                  1                   1               2
# 2        200501BS00003                  2                   1               1
# 3        200501BS00004                  1                   1               3
# 4        200501BS00005                  1                   1               1
# ...                ...                ...                 ...             ...
# 2216715  2014984137714                  1                   1               2
# 2216716  2014984138414                  1                   1               1
# 2216717  2014984138414                  2                   2               1
# 2216718  2014984139614                  1                   2               2
# 2216719  2014984139614                  2                   1               1
#
# ...

# %%
df_Casualties.columns
# Out:
# Index(['Accident_Index', 'Vehicle_Reference', 'Casualty_Reference',
#        'Casualty_Class', 'Sex_of_Casualty', 'Age_of_Casualty',
#        'Age_Band_of_Casualty', 'Casualty_Severity', 'Pedestrian_Location',
#        'Pedestrian_Movement', 'Car_Passenger', 'Bus_or_Coach_Passenger',
#        'Pedestrian_Road_Maintenance_Worker', 'Casualty_Type',
#        'Casualty_Home_Area_Type'],
#       dtype='object')

# %%
df_Casualties.drop(['Accident_Index'],axis='columns')
# Out:
#          Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0                        1                   1               3
# 1                        1                   1               2
# 2                        2                   1               1
# 3                        1                   1               3
# 4                        1                   1               1
# ...                    ...                 ...             ...
# 2216715                  1                   1               2
# 2216716                  1                   1               1
# 2216717                  2                   2               1
# 2216718                  1                   2               2
# 2216719                  2                   1               1
#
#          Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  \
# 0                      1               37                     7
# 1                      1               37                     7
# ...

# %%
df_Casualties.isna().sum()
# Out:
# Accident_Index                        0
# Vehicle_Reference                     0
# Casualty_Reference                    0
# Casualty_Class                        0
# Sex_of_Casualty                       0
# Age_of_Casualty                       0
# Age_Band_of_Casualty                  0
# Casualty_Severity                     0
# Pedestrian_Location                   0
# Pedestrian_Movement                   0
# Car_Passenger                         0
# Bus_or_Coach_Passenger                0
# Pedestrian_Road_Maintenance_Worker    0
# Casualty_Type                         0
# Casualty_Home_Area_Type               0
# dtype: int64

# %%
df_Vehicles
# Out:
#         Accident_Index  Vehicle_Reference  Vehicle_Type  \
# 0        200501BS00001                  1             9
# 1        200501BS00002                  1            11
# 2        200501BS00003                  1            11
# 3        200501BS00003                  2             9
# 4        200501BS00004                  1             9
# ...                ...                ...           ...
# 3004420  2014984138414                  1             9
# 3004421  2014984138414                  2            19
# 3004422  2014984138414                  3             9
# 3004423  2014984139614                  1            11
# 3004424  2014984139614                  2             9
#
#          Towing_and_Articulation  Vehicle_Manoeuvre  \
# 0                              0                 18
# 1                              0                  4
# 2                              0                 17
# 3                              0                  2
# ...

# %%
df_Vehicles.columns
# Out:
# Index(['Accident_Index', 'Vehicle_Reference', 'Vehicle_Type',
#        'Towing_and_Articulation', 'Vehicle_Manoeuvre',
#        'Vehicle_Location-Restricted_Lane', 'Junction_Location',
#        'Skidding_and_Overturning', 'Hit_Object_in_Carriageway',
#        'Vehicle_Leaving_Carriageway', 'Hit_Object_off_Carriageway',
#        '1st_Point_of_Impact', 'Was_Vehicle_Left_Hand_Drive?',
#        'Journey_Purpose_of_Driver', 'Sex_of_Driver', 'Age_of_Driver',
#        'Age_Band_of_Driver', 'Engine_Capacity_(CC)', 'Propulsion_Code',
#        'Age_of_Vehicle', 'Driver_IMD_Decile', 'Driver_Home_Area_Type'],
#       dtype='object')

# %%
df_Vehicles.drop(['Accident_Index'],axis='columns')
# Out:
#          Vehicle_Reference  Vehicle_Type  Towing_and_Articulation  \
# 0                        1             9                        0
# 1                        1            11                        0
# 2                        1            11                        0
# 3                        2             9                        0
# 4                        1             9                        0
# ...                    ...           ...                      ...
# 3004420                  1             9                        0
# 3004421                  2            19                        0
# 3004422                  3             9                        0
# 3004423                  1            11                        0
# 3004424                  2             9                        0
#
#          Vehicle_Manoeuvre  Vehicle_Location-Restricted_Lane  \
# 0                       18                                 0
# ...

# %%
df_Vehicles.isna().sum()
# Out:
# Accident_Index                      0
# Vehicle_Reference                   0
# Vehicle_Type                        0
# Towing_and_Articulation             0
# Vehicle_Manoeuvre                   0
# Vehicle_Location-Restricted_Lane    0
# Junction_Location                   0
# Skidding_and_Overturning            0
# Hit_Object_in_Carriageway           0
# Vehicle_Leaving_Carriageway         0
# Hit_Object_off_Carriageway          0
# 1st_Point_of_Impact                 0
# Was_Vehicle_Left_Hand_Drive?        0
# Journey_Purpose_of_Driver           0
# Sex_of_Driver                       0
# Age_of_Driver                       0
# Age_Band_of_Driver                  0
# Engine_Capacity_(CC)                0
# Propulsion_Code                     0
# Age_of_Vehicle                      0
# Driver_IMD_Decile                   0
# Driver_Home_Area_Type               0
# dtype: int64

# %%
df_Accidents
# Out:
#         Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0        200501BS00001               525680.0                178240.0
# 1        200501BS00002               524170.0                181650.0
# 2        200501BS00003               524520.0                182240.0
# 3        200501BS00004               526900.0                177530.0
# 4        200501BS00005               528060.0                179040.0
# ...                ...                    ...                     ...
# 1640592  2014984136414               310037.0                597647.0
# 1640593  2014984137514               321509.0                574063.0
# 1640594  2014984137714               321337.0                566365.0
# 1640595  2014984138414               323869.0                566853.0
# 1640596  2014984139614               314072.0                579971.0
#
#          Longitude   Latitude  Police_Force  Accident_Severity  \
# ...

# %%
df_Accidents.columns
# Out:
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location'],
#       dtype='object')

# %%
df_Accidents.drop(['Accident_Index','Longitude','Latitude'],axis='columns',inplace=True)

# %%
df_Accidents.isna().sum()
# Out:
# Location_Easting_OSGR                             111
# Location_Northing_OSGR                            111
# Police_Force                                        0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Number_of_Casualties                                0
# Date                                                0
# Day_of_Week                                         0
# Time                                              133
# Local_Authority_(District)                          0
# Local_Authority_(Highway)                           0
# 1st_Road_Class                                      0
# 1st_Road_Number                                     0
# Road_Type                                           0
# Speed_limit                                         0
# Junction_Detail                                     0
# Junction_Control                                    0
# ...

# %%
df_Accidents.dtypes
# Out:
# Location_Easting_OSGR                          float64
# Location_Northing_OSGR                         float64
# Police_Force                                     int64
# Accident_Severity                                int64
# Number_of_Vehicles                               int64
# Number_of_Casualties                             int64
# Date                                            object
# Day_of_Week                                      int64
# Time                                            object
# Local_Authority_(District)                       int64
# Local_Authority_(Highway)                       object
# 1st_Road_Class                                   int64
# 1st_Road_Number                                  int64
# Road_Type                                        int64
# Speed_limit                                      int64
# Junction_Detail                                  int64
# Junction_Control                                 int64
# ...

# %%
List = [df_Accidents, df_Casualties, df_Vehicles]
for j in range(0, len(List)):
    df_Accidents_columnslist = List[j].columns.copy()
    for i in range(0, len(df_Accidents_columnslist)):
        if List[j][df_Accidents_columnslist[i]].isnull().sum() != 0:
            print(df_Accidents_columnslist[i] , List[j][df_Accidents_columnslist[i]].isnull().sum())
            print("------------------------------------")
        i+=1
    j+=1
print("--End--")
# Out:
# Location_Easting_OSGR 111
# ------------------------------------
# Location_Northing_OSGR 111
# ------------------------------------
# Time 133
# ------------------------------------
# LSOA_of_Accident_Location 120574
# ------------------------------------
# --End--

# %%
import numpy as np

# %%
df_Accidents_copie = df_Accidents.copy()
for i in [df_Accidents_copie["Location_Easting_OSGR"],df_Accidents_copie["Location_Northing_OSGR"]]:
    i.fillna(np.mean(i), inplace = True)
df_Accidents_copie.drop(['LSOA_of_Accident_Location'],axis='columns', inplace=True)
df_Accidents_copie.isnull().sum()
# Out:
# Location_Easting_OSGR                            0
# Location_Northing_OSGR                           0
# Police_Force                                     0
# Accident_Severity                                0
# Number_of_Vehicles                               0
# Number_of_Casualties                             0
# Date                                             0
# Day_of_Week                                      0
# Time                                           133
# Local_Authority_(District)                       0
# Local_Authority_(Highway)                        0
# 1st_Road_Class                                   0
# 1st_Road_Number                                  0
# Road_Type                                        0
# Speed_limit                                      0
# Junction_Detail                                  0
# Junction_Control                                 0
# 2nd_Road_Class                                   0
# ...

# %%
df_Accidents_copie['Time']
# Out:
# 0          17:42
# 1          17:36
# 2          00:15
# 3          10:35
# 4          21:13
#            ...
# 1640592    22:20
# 1640593    06:40
# 1640594    02:00
# 1640595    06:55
# 1640596    15:00
# Name: Time, Length: 1640597, dtype: object

# %%
df_Accidents_copie['Time'].fillna(0, inplace=True)

# %%
df_Accidents_copie.isnull().sum()
# Out:
# Location_Easting_OSGR                          0
# Location_Northing_OSGR                         0
# Police_Force                                   0
# Accident_Severity                              0
# Number_of_Vehicles                             0
# Number_of_Casualties                           0
# Date                                           0
# Day_of_Week                                    0
# Time                                           0
# Local_Authority_(District)                     0
# Local_Authority_(Highway)                      0
# 1st_Road_Class                                 0
# 1st_Road_Number                                0
# Road_Type                                      0
# Speed_limit                                    0
# Junction_Detail                                0
# Junction_Control                               0
# 2nd_Road_Class                                 0
# 2nd_Road_Number                                0
# ...
